# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 4423 (delta 1), reused 2 (delta 0), pack-reused 4416
# Receiving objects: 100% (4423/4423), 7.40 MiB | 35.89 MiB/s, done.
# Resolving deltas: 100% (3001/3001), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !python train.py --img 1920 --batch 4 --epochs 300 --data training/dataset.yaml --cfg training/yolov5s.yaml --weights '' --device 0
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 v4.0-45-g8fcbe43 torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=False, cfg='training/yolov5s.yaml', data='training/dataset.yaml', device='0', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1920, 1920], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp', single_cls=False, sync_bn=False, total_batch_size=4, weights='', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 1920 --source ../yolov5/test/images
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=1920, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../yolov5/test/images', update=False, view_img=False, weights=['runs/train/exp/weights/best.pt'])
# YOLOv5 v4.0-46-gd68afed torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/7 /content/yolov5/test/images/www.9gag.com.png: 1088x1920 68 Elements, Done. (0.030s)
# image 2/7 /content/yolov5/test/images/www.aldi.co.uk.png: 1088x1920 28 Elements, Done. (0.028s)
# image 3/7 /content/yolov5/test/images/www.allegro.pl.png: 1088x1920 52 Elements, Done. (0.028s)
# image 4/7 /content/yolov5/test/images/www.reddit.com.png: 1088x1920 73 Elements, Done. (0.028s)
# image 5/7 /content/yolov5/test/images/www.wikia.com.png: 1088x1920 53 Elements, Done. (0.028s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source ../yolov5/test/video/test2.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../yolov5/test/video/test2.mp4', update=False, view_img=False, weights=['runs/train/exp/weights/best.pt'])
# YOLOv5 v4.0-46-gd68afed torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# video 1/1 (1/1083) /content/yolov5/test/video/test2.mp4: 384x640 22 Elements, Done. (0.011s)
# video 1/1 (2/1083) /content/yolov5/test/video/test2.mp4: 384x640 23 Elements, Done. (0.010s)
# video 1/1 (3/1083) /content/yolov5/test/video/test2.mp4: 384x640 23 Elements, Done. (0.009s)
# video 1/1 (4/1083) /content/yolov5/test/video/test2.mp4: 384x640 23 Elements, Done. (0.009s)
# video 1/1 (5/1083) /content/yolov5/test/video/test2.mp4: 384x640 23 Elements, Done. (0.009s)
# ...
